# %%
import pandas as pd

import numpy as np

import seaborn as sms

import matplotlib.pyplot as plt

# %%
df=pd.read_json('iris.json')

df
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
#df.head() 
# prints top elements

#df.tail()
# prints bottom elements

# df.sample(5) 
# prints random values

# df.info() 
# gives info of data

# df.columns 
# shows cloumns data

# df.shape 
# specifires the shape

# rows,cols=df.shape
# print(f"rows:{rows},cloumns:{cols}")


# df.dtypes
#defines the data type used in the data
# df["species"]=df["species"].astype("category")
# df["species"].dtype

# df.mean(numeric_only=True)
#df.median(numeric_only=True)
#df.mode(numeric_only=True)
# print(df['species'].mode())

# df.std(numeric_only=True)
# df.min()
# df.max()

# data_range=df.max(numeric_only=True)-df.min(numeric_only=True)
# print("The range of iris dataset is\n",data_range)

# %%
for column in df.columns:
    plt.figure(figsize=(6,4))
    sms.histplot(df[column],kde=True,color='red')
    plt.title(f'Gaussian Distribution of{column}')
    plt.xlabel('column')
    plt.ylabel('Density')
    plt.grid(False)
    plt.show()

# %%
# Calculate Q1 and Q3
Q1 = df.quantile(0.25,numeric_only=True)
Q3 = df.quantile(0.75,numeric_only=True)

# Calculate IQR
IQR = Q3 - Q1

print("Interquartile Range (IQR):")
print(IQR)
# Out:
# Interquartile Range (IQR):
# sepalLength    1.3
# sepalWidth     0.5
# petalLength    3.5
# petalWidth     1.5
# dtype: float64

# %%
summary=df.describe()   #(Displays statistical summary)

summary
# Out:
#        sepalLength  sepalWidth  petalLength  petalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.057333     3.758000    1.199333
# std       0.828066    0.435866     1.765298    0.762238
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
#Review Class Distribution

class_counts=df['species'].value_counts()
print(class_counts)
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)
df
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
#Create heatmap

plt.Figure(figsize=(8,6))
sms.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm',linewidths=0.5)
plt.title('correlation heatmap of iris dataset')
plt.show()

# %%
#calculate skewness

skew_values=df.skew(numeric_only=True)
print('Skewness of each feature:')
print(skew_values)

#plot the distributions to visualise skewness

for column in df.columns:
    sms.histplot(df[column],kde=True)
    plt.title(f'Distribution and skewness of{column}')
    plt.xlabel('Column')
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Skewness of each feature:
# sepalLength    0.314911
# sepalWidth     0.318966
# petalLength   -0.274884
# petalWidth    -0.102967
# dtype: float64

# %%
plt.figure(figsize=(6,4))
sms.barplot(x='species',y='sepalLength',data=df,estimator=np.mean)
plt.title('Mean Sepal Length by Species')
plt.xlabel('Species')
plt.ylabel('Average sepal length')
plt.show()

# %%
#Count Plot

plt.figure(figsize=(6,4))
sms.countplot(x='species',data=df)
plt.title('Count Plot of Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()

# %%
# Pie Chart

species_count = df['species'].value_counts()

plt.figure(figsize=(6,4))
plt.pie(species_count, labels=species_count.index, autopct='%1.1f%%', startangle=120)
plt.title("Distribution of Species")
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['sepalLength'],bins=10,color='green',edgecolor='black')
plt.title('Histogram of sepal length')
plt.xlabel('sepal length')
plt.ylabel('frequency')
plt.show()

# %%
plt.figure(figsize=(6,4))
sms.kdeplot(df['sepalWidth'],fill='True',color='blue')
plt.title('Density Plot of Sepal Width')
plt.xlabel('sepal width')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize=(6,2))
sms.boxplot(x=df['sepalLength'],color='orange')
plt.title('box plot of sepal length')
plt.xlabel('Sepal Length')
plt.show()

# %%
sms.scatterplot(x='sepalWidth',y='petalWidth',data=df)
plt.title("Scatter plot:sepal width vs petal width")
plt.xlabel('Sepal width')
plt.ylabel('petal width')
plt.show()

# %%
sms.lineplot(x=df.index,y='sepalLength',data=df)
plt.title('Line plot:sepal length over Index')
plt.xlabel('Index')
plt.ylabel('Sepal length')
plt.show()

# %%
sms.boxplot(x='sepalLength',y='species',data=df)
plt.title('Boxplot:Sepal Length by Species')
plt.show()

# %%
sms.violinplot(y='sepalLength',x='species',data=df)
plt.title('Violinplot:Sepal Length by Species')
plt.show()

# %%
sms.swarmplot(y='sepalLength',x='species',data=df)
plt.title('Swarnplot:Sepal Length by Species')
plt.xlabel('species')
plt.ylabel('sepal length (cm)')
plt.show()

# %%
plt.hist2d(df['sepalWidth'],df['petalWidth'],bins=30,cmap='Reds')
plt.colorbar(label='Count in bin')
plt.title('2D Histogram: Sepal Width vs Petal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Width')
plt.show()

# %%
sms.lineplot(x=df.index,y='petalWidth',hue='species',data=df)
plt.title('Line plot: Petal Width by Species')
plt.xlabel('sample index')
plt.ylabel('petal width')
plt.legend(title='species')
plt.show()

# %%
#add a new categorical column with 3 flower types

def assign_flower_type(species):
    if species=='setosa':
        return 'Type A'
    elif species=='versicolor':
        return'Type B'
    else:
        return 'Type C'

df['flower_type']=df['species'].apply(assign_flower_type)

contigency_table=pd.crosstab(df['species'],df['flower_type'])
print(contigency_table)
# Out:
# flower_type  Type A  Type B  Type C
# species
# setosa           50       0       0
# versicolor        0      50       0
# virginica         0       0      50

# %%
corr=df[['sepalLength','sepalWidth','petalLength','petalWidth']].corr()

sms.heatmap(corr,annot=True,cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(df[['sepalLength','sepalWidth','petalLength','petalWidth']],figsize=(10,8),diagonal='kde')

plt.suptitle("Scatter plot matrix")
plt.show()
