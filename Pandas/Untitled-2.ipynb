# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('2.xlsx',sheet_name='Sheet1')

df
# Out:
#          Day  Temperature  Windspeed   Event
# 0 2025-01-01         32.0       45.0   Rainy
# 1 2025-01-02          0.0       23.0     NaN
# 2 2025-01-03         27.0       54.0  Cloudy
# 3 2025-01-04         23.0       56.0   Sunny
# 4 2025-01-05          NaN        NaN     NaN
# 5 2025-01-06          0.0       56.0   Sunny
# 6 2025-01-07         19.0       23.0  Cloudy
# 7 2025-01-08          NaN       78.0   Sunny
# 8 2025-01-09          NaN       45.0     NaN

# %%
df.set_index("Day",inplace=True)

df
# Out:
#             Temperature  Windspeed   Event
# Day
# 2025-01-01         32.0       45.0   Rainy
# 2025-01-02          0.0       23.0     NaN
# 2025-01-03         27.0       54.0  Cloudy
# 2025-01-04         23.0       56.0   Sunny
# 2025-01-05          NaN        NaN     NaN
# 2025-01-06          0.0       56.0   Sunny
# 2025-01-07         19.0       23.0  Cloudy
# 2025-01-08          NaN       78.0   Sunny
# 2025-01-09          NaN       45.0     NaN

# %%
df=pd.read_excel('2.xlsx',sheet_name='Sheet1')


g=df.columns.str.strip()

g
# Out:
# Index(['Day', 'Temperature', 'Windspeed', 'Event'], dtype='object')

# %%
new_df1=df.fillna(10)

new_df1
# Out:
#          Day  Temperature  Windspeed   Event
# 0 2025-01-01         32.0       45.0   Rainy
# 1 2025-01-02          0.0       23.0      10
# 2 2025-01-03         27.0       54.0  Cloudy
# 3 2025-01-04         23.0       56.0   Sunny
# 4 2025-01-05         10.0       10.0      10
# 5 2025-01-06          0.0       56.0   Sunny
# 6 2025-01-07         19.0       23.0  Cloudy
# 7 2025-01-08         10.0       78.0   Sunny
# 8 2025-01-09         10.0       45.0      10

# %%
new_df=df.fillna({
    "Temperature":20,
    "Windspeed":0,
    "Event":"No Event"
})

new_df
# Out:
#          Day  Temperature  Windspeed     Event
# 0 2025-01-01         32.0       45.0     Rainy
# 1 2025-01-02          0.0       23.0  No Event
# 2 2025-01-03         27.0       54.0    Cloudy
# 3 2025-01-04         23.0       56.0     Sunny
# 4 2025-01-05         20.0        0.0  No Event
# 5 2025-01-06          0.0       56.0     Sunny
# 6 2025-01-07         19.0       23.0    Cloudy
# 7 2025-01-08         20.0       78.0     Sunny
# 8 2025-01-09         20.0       45.0  No Event

# %%
new_df=df.ffill()

new_df
# Out:
#          Day  Temperature  Windspeed   Event
# 0 2025-01-01         32.0       45.0   Rainy
# 1 2025-01-02          0.0       23.0   Rainy
# 2 2025-01-03         27.0       54.0  Cloudy
# 3 2025-01-04         23.0       56.0   Sunny
# 4 2025-01-05         23.0       56.0   Sunny
# 5 2025-01-06          0.0       56.0   Sunny
# 6 2025-01-07         19.0       23.0  Cloudy
# 7 2025-01-08         19.0       78.0   Sunny
# 8 2025-01-09         19.0       45.0   Sunny

# %%
df=df.replace(0,np.nan).ffill()

df
# Out:
#          Day  Temperature  Windspeed   Event
# 0 2025-01-01         32.0       45.0   Rainy
# 1 2025-01-02         32.0       23.0   Rainy
# 2 2025-01-03         27.0       54.0  Cloudy
# 3 2025-01-04         23.0       56.0   Sunny
# 4 2025-01-05         23.0       56.0   Sunny
# 5 2025-01-06         23.0       56.0   Sunny
# 6 2025-01-07         19.0       23.0  Cloudy
# 7 2025-01-08         19.0       78.0   Sunny
# 8 2025-01-09         19.0       45.0   Sunny

# %%
df=pd.read_excel('3.xlsx',sheet_name='Sheet1')

df
# Out:
#          Day  Temperature Windspeed   Event
# 0 2025-01-01         32.0   45 Kmph   Rainy
# 1 2025-01-02          0.0   23 kmph     NaN
# 2 2025-01-03         27.0   54 Kmph  Cloudy
# 3 2025-01-04         23.0   56 Kmph   Sunny
# 4 2025-01-05          NaN  NaN Kmph     NaN
# 5 2025-01-06          0.0   56 kmph   Sunny
# 6 2025-01-07         19.0   23 Kmph  Cloudy
# 7 2025-01-08          NaN   78 Kmph   Sunny
# 8 2025-01-09          NaN   45 Kmph     NaN

# %%
new_df=df.replace({
    "Windspeed":"[A-Za-z]",
    "Event":"[A-Za-z]",
    "Temperature":"[A-Za-z]"
}," ",regex=True)

new_df
# Out:
#          Day  Temperature Windspeed   Event
# 0 2025-01-01         32.0   45
# 1 2025-01-02          0.0   23          NaN
# 2 2025-01-03         27.0   54
# 3 2025-01-04         23.0   56
# 4 2025-01-05          NaN               NaN
# 5 2025-01-06          0.0   56
# 6 2025-01-07         19.0   23
# 7 2025-01-08          NaN   78
# 8 2025-01-09          NaN   45          NaN

# %%
df_1=pd.DataFrame({
    "marks":["poor","average","good","excellent"],
    "students":["John","Jane","Doe","Smith"]
})

df_1.replace(["poor","average","good","excellent"],["F","C","B","A"])
# Out:
#   marks students
# 0     F     John
# 1     C     Jane
# 2     B      Doe
# 3     A    Smith

# %%
df=pd.read_excel('4.xlsx',sheet_name='Sheet1')

df
# Out:
#         Date     City  Temp
# 0 2025-01-01     BBSR    35
# 1 2025-01-02     BBSR    40
# 2 2025-01-03     BBSR    45
# 3 2025-01-04     BBSR    39
# 4 2025-01-05  Cuttack    32
# 5 2025-01-06  Cuttack    30
# 6 2025-01-07  Cuttack    49
# 7 2025-01-08  Cuttack    40
# 8 2025-01-09  Cuttack    45
# 9 2025-01-10  Cuttack    31

# %%
g=df.columns.str.strip()

g
# Out:
# Index(['Date', 'City', 'Temp'], dtype='object')

# %%
g=df.groupby("City")

g

# %%
for City, group in g:
    print(f"City: {City}")
    print(group)
    print("\n")

df.Temp.max()
# Out:
# City: BBSR
#         Date  City  Temp
# 0 2025-01-01  BBSR    35
# 1 2025-01-02  BBSR    40
# 2 2025-01-03  BBSR    45
# 3 2025-01-04  BBSR    39
#
#
# City: Cuttack
#         Date     City  Temp
# 4 2025-01-05  Cuttack    32
# 5 2025-01-06  Cuttack    30
# 6 2025-01-07  Cuttack    49
# 7 2025-01-08  Cuttack    40
# 8 2025-01-09  Cuttack    45
# 9 2025-01-10  Cuttack    31
# np.int64(49)

# %%
g.get_group("BBSR")
# Out:
#         Date  City  Temp
# 0 2025-01-01  BBSR    35
# 1 2025-01-02  BBSR    40
# 2 2025-01-03  BBSR    45
# 3 2025-01-04  BBSR    39

# %%
g.max()
# Out:
#               Date  Temp
# City
# BBSR    2025-01-04    45
# Cuttack 2025-01-10    49

# %%
g.mean()
# Out:
#                        Date       Temp
# City
# BBSR    2025-01-02 12:00:00  39.750000
# Cuttack 2025-01-07 12:00:00  37.833333

# %%
g=df.groupby('City')

# %%
import matplotlib.pyplot as plt

g=df.groupby('City')['Temp'].mean()
colors=['red','green','blue']

g.plot(kind='bar',color=colors,title='Mean Temperature by City')

plt.ylabel('Mean Temperature')

plt.xlabel('City')

plt.show()
